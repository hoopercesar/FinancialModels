# %%
# !pip install alpha_vantage
# Out:
# Collecting alpha_vantage
#   Downloading alpha_vantage-2.3.1-py3-none-any.whl (31 kB)
# Collecting aiohttp (from alpha_vantage)
#   Downloading aiohttp-3.8.4-cp38-cp38-win_amd64.whl (324 kB)
#      ------------------------------------ 324.5/324.5 kB 774.0 kB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\cesar hooper\anaconda\anaconda3\lib\site-packages (from alpha_vantage) (2.30.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\cesar hooper\anaconda\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (20.3.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\cesar hooper\anaconda\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (3.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->alpha_vantage)
#   Downloading multidict-6.0.4-cp38-cp38-win_amd64.whl (28 kB)
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->alpha_vantage)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->alpha_vantage)
#   Downloading yarl-1.9.2-cp38-cp38-win_amd64.whl (61 kB)
#      ---------------------------------------- 61.8/61.8 kB 1.1 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->alpha_vantage)
#   Downloading frozenlist-1.3.3-cp38-cp38-win_amd64.whl (34 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->alpha_vantage)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cesar hooper\anaconda\anaconda3\lib\site-packages (from requests->alpha_vantage) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cesar hooper\anaconda\anaconda3\lib\site-packages (from requests->alpha_vantage) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cesar hooper\anaconda\anaconda3\lib\site-packages (from requests->alpha_vantage) (2020.12.5)
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, alpha_vantage
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 alpha_vantage-2.3.1 async-timeout-4.0.2 frozenlist-1.3.3 multidict-6.0.4 yarl-1.9.2

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from alpha_vantage.timeseries import TimeSeries

# %%
api_key = 'XJ1Y0V6MI2Z4JT73'

# %%
ts = TimeSeries(key=api_key, output_format='pandas')
data, meta_data = ts.get_intraday(symbol='AMZN',interval='1min', outputsize='full')
data['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()

# %%
data.head(20)
# Out:
#                      1. open  2. high    3. low  4. close  5. volume
# date
# 2023-06-06 19:59:00   126.49   126.49  126.4500  126.4700     3041.0
# 2023-06-06 19:58:00   126.49   126.49  126.4500  126.4500     2410.0
# 2023-06-06 19:57:00   126.45   126.45  126.4500  126.4500      335.0
# 2023-06-06 19:56:00   126.55   126.55  126.4500  126.4600     2071.0
# 2023-06-06 19:55:00   126.55   126.55  126.4900  126.4900     1144.0
# 2023-06-06 19:54:00   126.48   126.53  126.4800  126.5300     2018.0
# 2023-06-06 19:53:00   126.45   126.46  126.4500  126.4500      593.0
# 2023-06-06 19:52:00   126.46   126.46  126.4600  126.4600      502.0
# 2023-06-06 19:51:00   126.49   126.49  126.4900  126.4900      521.0
# 2023-06-06 19:50:00   126.46   126.49  126.4600  126.4900      796.0
# 2023-06-06 19:49:00   126.46   126.46  126.4600  126.4600      336.0
# 2023-06-06 19:46:00   126.48   126.48  126.4800  126.4800      545.0
# 2023-06-06 19:45:00   126.49   126.49  126.4900  126.4900      227.0
# 2023-06-06 19:44:00   126.45   126.45  126.4500  126.4500      361.0
# 2023-06-06 19:42:00   126.49   126.49  126.4900  126.4900     3783.0
# 2023-06-06 19:40:00   126.49   126.49  126.4900  126.4900      183.0
# 2023-06-06 19:38:00   126.51   126.51  126.5000  126.5000     2580.0
# 2023-06-06 19:37:00   126.55   126.55  126.5500  126.5500      235.0
# 2023-06-06 19:34:00   126.55   126.55  126.5499  126.5499     2032.0
# 2023-06-06 19:33:00   126.50   126.50  126.5000  126.5000      176.0
